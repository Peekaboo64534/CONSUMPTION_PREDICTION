# %%
import pandas as pd

df = pd.read_csv('/Users/peekaboo645/code/Peekaboo64534/project_name/CONSUMPTION_PREDICTION/final_dataset.csv')
df
# Out:
#          datetime  homeid  gas (kWh)  Consumption (kWh)  Total (kWh)  \
# 0      2018-02-21     299     21.603           3.725250    25.328250
# 1      2018-02-22     299     23.288           3.692155    26.980155
# 2      2018-02-23     299     30.005           3.922362    33.927362
# 3      2018-02-24     299     31.113           4.658932    35.771932
# 4      2018-02-27     299     47.230           3.894231    51.124231
# ...           ...     ...        ...                ...          ...
# 45110  2018-06-24     280     30.202          15.034794    45.236794
# 45111  2018-06-25     280     19.008          11.688886    30.696886
# 45112  2018-06-26     280     20.690          11.550507    32.240507
# 45113  2018-06-29     280     12.190          10.084057    22.274057
# 45114  2018-06-30     280     15.549           8.060609    23.609609
#
#        temp_mean  temp_min  temp_max  location_id location_name  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# datetime                0
# homeid                  0
# gas (kWh)               0
# Consumption (kWh)       0
# Total (kWh)             0
# temp_mean               0
# temp_min                0
# temp_max                0
# location_id             0
# location_name           0
# residents               0
# hometype                0
# occupied_days           0
# occupied_nights         0
# entry_floor             0
# income_band_num         0
# electric_appliance      0
# gas_appliance           0
# total_area              0
# room_count              0
# windowsopen             0
# mean_h                294
# min_h                 294
# max_h                 294
# mean_t                594
# min_t                 594
# max_t                 594
# dtype: int64

# %%
df.describe()
# Out:
#              homeid     gas (kWh)  Consumption (kWh)   Total (kWh)  \
# count  45114.000000  45114.000000       45114.000000  45114.000000
# mean     165.181828     41.521364           8.563922     50.085286
# std       76.423919     60.378213           5.141998     62.075831
# min       59.000000      0.000000           0.192421      0.224733
# 25%       96.000000      6.952000           4.964030     14.483484
# 50%      157.000000     24.689500           7.627546     32.572820
# 75%      227.000000     57.542500          10.999277     67.383782
# max      335.000000   3706.452000         102.616242   3715.519872
#
#           temp_mean      temp_min      temp_max   location_id     residents  \
# count  45114.000000  45114.000000  45114.000000  45114.000000  45114.000000
# mean       8.846782      5.772807     12.269393      5.287915      2.424635
# std        5.197981      4.671606      6.279259      8.884543      1.071557
# ...

# %%
df.dtypes
# Out:
# datetime               object
# homeid                  int64
# gas (kWh)             float64
# Consumption (kWh)     float64
# Total (kWh)           float64
# temp_mean             float64
# temp_min              float64
# temp_max              float64
# location_id             int64
# location_name          object
# residents               int64
# hometype               object
# occupied_days           int64
# occupied_nights         int64
# entry_floor             int64
# income_band_num         int64
# electric_appliance      int64
# gas_appliance           int64
# total_area              int64
# room_count              int64
# windowsopen             int64
# mean_h                float64
# min_h                 float64
# max_h                 float64
# mean_t                float64
# min_t                 float64
# max_t                 float64
# dtype: object

# %%
df.nunique()
# Out:
# datetime                584
# homeid                  236
# gas (kWh)             17797
# Consumption (kWh)     45103
# Total (kWh)           45112
# temp_mean              1379
# temp_min                219
# temp_max                269
# location_id               5
# location_name             5
# residents                 6
# hometype                  2
# occupied_days             8
# occupied_nights           7
# entry_floor               8
# income_band_num          16
# electric_appliance       11
# gas_appliance             6
# total_area              140
# room_count               12
# windowsopen              10
# mean_h                44816
# min_h                   709
# max_h                   770
# mean_t                42136
# min_t                   256
# max_t                   269
# dtype: int64

# %%
#len(df.index) - df.count()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45115 entries, 0 to 45114
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            45115 non-null  object
#  1   homeid              45115 non-null  int64
#  2   gas (kWh)           45115 non-null  float64
#  3   Consumption (kWh)   45115 non-null  float64
#  4   Total (kWh)         45115 non-null  float64
#  5   temp_mean           45115 non-null  float64
#  6   temp_min            45115 non-null  float64
#  7   temp_max            45115 non-null  float64
#  8   location_id         45115 non-null  int64
#  9   location_name       45115 non-null  object
#  10  residents           45115 non-null  int64
#  11  hometype            45115 non-null  object
#  12  occupied_days       45115 non-null  int64
#  13  occupied_nights     45115 non-null  int64
#  14  entry_floor         45115 non-null  int64
# ...

# %%
X = data_train.drop([''], axis=1) # myFeatures
y = data_train['']  # myTargetVariable

# %%
df.isnull().sum().sum()
# Out:
# 2664

# %%
df.isnull().any()
# Out:
# datetime              False
# homeid                False
# gas (kWh)             False
# Consumption (kWh)     False
# Total (kWh)           False
# temp_mean             False
# temp_min              False
# temp_max              False
# location_id           False
# location_name         False
# residents             False
# hometype              False
# occupied_days         False
# occupied_nights       False
# entry_floor           False
# income_band_num       False
# electric_appliance    False
# gas_appliance         False
# total_area            False
# room_count            False
# windowsopen           False
# mean_h                 True
# min_h                  True
# max_h                  True
# mean_t                 True
# min_t                  True
# max_t                  True
# dtype: bool

# %%
df_0=df[df['Total (kWh)'] < 0]

# %%
df_0
# Out:
#          datetime  homeid  gas (kWh)  Consumption (kWh)  Total (kWh)  \
# 19302  2017-11-21     188   -388.834            6.12371   -382.71029
#
#        temp_mean  temp_min  temp_max  location_id location_name  ...  \
# 19302   8.965278       6.9      12.0            1     Edinburgh  ...
#
#        gas_appliance total_area  room_count  windowsopen     mean_h  min_h  \
# 19302              4        880           9            5  684.04111  650.0
#
#        max_h      mean_t  min_t  max_t
# 19302  754.0  179.306957  168.0  200.0
#
# [1 rows x 27 columns]

# %%
df_1 = df[df['gas (kWh)'] > 300 ]

# %%
df_1
# Out:
#          datetime  homeid  gas (kWh)  Consumption (kWh)  Total (kWh)  \
# 1266   2017-12-01     138    306.479           9.428746   315.907746
# 1274   2017-12-09     138    456.233          12.118741   468.351741
# 1280   2017-12-15     138    463.180           7.845675   471.025675
# 1281   2017-12-16     138    302.068          10.427555   312.495555
# 1848   2017-12-20     105    393.736           7.133099   400.869099
# ...           ...     ...        ...                ...          ...
# 44637  2018-03-01     257    301.419           8.947674   310.366674
# 44638  2018-03-02     257    307.535           5.547382   313.082382
# 44729  2017-12-11     243   1007.981           7.734447  1015.715447
# 44782  2018-02-10     243    370.862          10.962046   381.824046
# 44787  2018-02-17     243    321.295           5.251381   326.546381
#
#        temp_mean  temp_min  temp_max  location_id location_name  ...  \
# ...

# %%
df.iloc[19302]
# Out:
# datetime              2017-11-21
# homeid                       188
# gas (kWh)               -388.834
# Consumption (kWh)        6.12371
# Total (kWh)           -382.71029
# temp_mean               8.965278
# temp_min                     6.9
# temp_max                    12.0
# location_id                    1
# location_name          Edinburgh
# residents                      3
# hometype                    flat
# occupied_days                  4
# occupied_nights                7
# entry_floor                    0
# income_band_num               15
# electric_appliance             6
# gas_appliance                  4
# total_area                   880
# room_count                     9
# windowsopen                    5
# mean_h                 684.04111
# min_h                      650.0
# max_h                      754.0
# mean_t                179.306957
# min_t                      168.0
# max_t                      200.0
# Name: 19302, dtype: object

# %%
df = df.drop(19302)

# %% [markdown]
# BASELINE MEAN MODEL -TOTAL kWh

# %%
baseline_prediction = df['Total (kWh)'].mean()
baseline_error = ((df['Total (kWh)'] - baseline_prediction) ** 2).mean()

# %%
baseline_prediction
# Out:
# 50.08528642468709

# %%
baseline_error
# Out:
# 3853.3233714282846

# %%
! pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 20.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.8/260.8 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 18.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 12.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# LINEAR REGRESSION

# %%
# Drop na values in existing dataframe
df.dropna(inplace=True)

# if you want to create new dataframe with dropped values from original dataframe
df_new = df.dropna()

# Define X and y
X = df_new.drop(columns=['Total (kWh)']).copy()
y = df_new['Total (kWh)'].copy()
# Out:
#          datetime  homeid  gas (kWh)  Consumption (kWh)  Total (kWh)  \
# 0      2018-02-21     299     21.603           3.725250    25.328250
# 1      2018-02-22     299     23.288           3.692155    26.980155
# 2      2018-02-23     299     30.005           3.922362    33.927362
# 3      2018-02-24     299     31.113           4.658932    35.771932
# 4      2018-02-27     299     47.230           3.894231    51.124231
# ...           ...     ...        ...                ...          ...
# 45110  2018-06-24     280     30.202          15.034794    45.236794
# 45111  2018-06-25     280     19.008          11.688886    30.696886
# 45112  2018-06-26     280     20.690          11.550507    32.240507
# 45113  2018-06-29     280     12.190          10.084057    22.274057
# 45114  2018-06-30     280     15.549           8.060609    23.609609
#
#        temp_mean  temp_min  temp_max  location_id location_name  ...  \
# ...

# %%
df_lin= df.drop(columns=['Total (kWh)'])

# %%
df_lin= df.dropna(inplace = True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
display(df_lin)
# Out:
# None

# %%
X = df_lin
y = df['Total (kWh)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)


model= LinearRegression

model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
#       4 model= LinearRegression
#       6 model.fit(X_train,y_train)
#
# File ~/.pyenv/versions/3.10.6/envs/CONSUMPTION_PREDICTION/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...
