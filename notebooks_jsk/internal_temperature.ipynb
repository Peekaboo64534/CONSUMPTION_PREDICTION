# %%
import pandas as pd
import os

# %%
# Check directory and save all file names
directory = r"../data_jsk/original/"
file_names = []

for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_names.append(filename)

# %%
# Function to transform datafiles
def transform_data(directory, file_name):

    # Read data
    df = pd.read_csv(directory + file_name)

    # Rename columns to datetime and humidity
    df.columns = ['datetime', 'temperature']

    # Convert datetime to datetime object
    df['datetime'] = pd.to_datetime(df['datetime'])

    # add 2 more columns in order to min and max values
    df['min_t'] = df['temperature']
    df['max_t'] = df['temperature']

    # resample and get mean, min and max values
    df_new = df.resample('D', on='datetime').agg({'temperature':'mean', 'min_t':'min', 'max_t':'max'})
    df_new.reset_index(inplace=True)
    df_new.rename(columns={'temperature':'mean_t'}, inplace=True)
    df_new['homeid'] = file_name.split('home')[1].split('.')[0]

    return df_new

# %%
# export dataframe to csv file and delete original file
def export_file(df, file_name):
    df.to_csv('../data_jsk/temperature_transformed/' + file_name, index=False)
    print(f'{file_name} exported successfully!')

    original_path = directory + file_name

    if os.path.exists(original_path):
        os.remove(original_path)
        print(f'Original {file_name} deleted successfully!')
        print('----------------------------------------------\n')

# %%
# loop through all files in the directory and transform them
status = 1
for file_name in file_names:
    print(f'Processing file {status} of {len(file_names)}')
    df = transform_data(directory, file_name)
    export_file(df, file_name)
    status += 1
# Out:
# Processing file 1 of 254
# home299.csv exported successfully!
# Original home299.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 2 of 254
# home266.csv exported successfully!
# Original home266.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 3 of 254
# home272.csv exported successfully!
# Original home272.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 4 of 254
# home306.csv exported successfully!
# Original home306.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 5 of 254
# home69.csv exported successfully!
# Original home69.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 6 of 254
# home110.csv exported successfully!
# Original home110.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 7 of 254
# home96.csv exported successfully!
# Original home96.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 8 of 254
# home82.csv exported successfully!
# Original home82.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 9 of 254
# home138.csv exported successfully!
# Original home138.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 10 of 254
# home139.csv exported successfully!
# Original home139.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 11 of 254
# home83.csv exported successfully!
# Original home83.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 12 of 254
# home105.csv exported successfully!
# Original home105.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 13 of 254
# home97.csv exported successfully!
# Original home97.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 14 of 254
# home68.csv exported successfully!
# Original home68.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 15 of 254
# home307.csv exported successfully!
# Original home307.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 16 of 254
# home313.csv exported successfully!
# Original home313.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 17 of 254
# home273.csv exported successfully!
# Original home273.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 18 of 254
# home267.csv exported successfully!
# Original home267.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 19 of 254
# home298.csv exported successfully!
# Original home298.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 20 of 254
# home271.csv exported successfully!
# Original home271.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 21 of 254
# home265.csv exported successfully!
# Original home265.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 22 of 254
# home259.csv exported successfully!
# Original home259.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 23 of 254
# home305.csv exported successfully!
# Original home305.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 24 of 254
# home311.csv exported successfully!
# Original home311.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 25 of 254
# home107.csv exported successfully!
# Original home107.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 26 of 254
# home81.csv exported successfully!
# Original home81.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 27 of 254
# home113.csv exported successfully!
# Original home113.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 28 of 254
# home94.csv exported successfully!
# Original home94.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 29 of 254
# home106.csv exported successfully!
# Original home106.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 30 of 254
# home80.csv exported successfully!
# Original home80.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 31 of 254
# home310.csv exported successfully!
# Original home310.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 32 of 254
# home304.csv exported successfully!
# Original home304.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 33 of 254
# home258.csv exported successfully!
# Original home258.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 34 of 254
# home264.csv exported successfully!
# Original home264.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 35 of 254
# home270.csv exported successfully!
# Original home270.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 36 of 254
# home248.csv exported successfully!
# Original home248.csv deleted successfully!
# ----------------------------------------------
#
# Processing file
csv deleted successfully!
# ----------------------------------------------
#
# Processing file 219 of 254
# home72.csv exported successfully!
# Original home72.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 220 of 254
# home99.csv exported successfully!
# Original home99.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 221 of 254
# home123.csv exported successfully!
# Original home123.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 222 of 254
# home137.csv exported successfully!
# Original home137.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 223 of 254
# home136.csv exported successfully!
# Original home136.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 224 of 254
# home122.csv exported successfully!
# Original home122.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 225 of 254
# home98.csv exported successfully!
# Original home98.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 226 of 254
# home73.csv exported successfully!
# Original home73.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 227 of 254
# home67.csv exported successfully!
# Original home67.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 228 of 254
# home334.csv exported successfully!
# Original home334.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 229 of 254
# home320.csv exported successfully!
# Original home320.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 230 of 254
# home308.csv exported successfully!
# Original home308.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 231 of 254
# home240.csv exported successfully!
# Original home240.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 232 of 254
# home254.csv exported successfully!
# Original home254.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 233 of 254
# home268.csv exported successfully!
# Original home268.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 234 of 254
# home283.csv exported successfully!
# Original home283.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 235 of 254
# home281.csv exported successfully!
# Original home281.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 236 of 254
# home295.csv exported successfully!
# Original home295.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 237 of 254
# home242.csv exported successfully!
# Original home242.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 238 of 254
# home256.csv exported successfully!
# Original home256.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 239 of 254
# home322.csv exported successfully!
# Original home322.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 240 of 254
# home59.csv exported successfully!
# Original home59.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 241 of 254
# home71.csv exported successfully!
# Original home71.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 242 of 254
# home65.csv exported successfully!
# Original home65.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 243 of 254
# home134.csv exported successfully!
# Original home134.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 244 of 254
# home120.csv exported successfully!
# Original home120.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 245 of 254
# home121.csv exported successfully!
# Original home121.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 246 of 254
# home135.csv exported successfully!
# Original home135.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 247 of 254
# home109.csv exported successfully!
# Original home109.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 248 of 254
# home64.csv exported successfully!
# Original home64.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 249 of 254
# home70.csv exported successfully!
# Original home70.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 250 of 254
# home323.csv exported successfully!
# Original home323.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 251 of 254
# home257.csv exported successfully!
# Original home257.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 252 of 254
# home243.csv exported successfully!
# Original home243.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 253 of 254
# home294.csv exported successfully!
# Original home294.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 254 of 254
# home280.csv exported successfully!
# Original home280.csv deleted successfully!
# ----------------------------------------------

# %% [markdown]
# ### Combine all the humidity data in one dataset

# %%
# Humidity directory
dir_hum = r"../data_jsk/temperature_transformed/"

file_names = []

# Iterate over files in directory
for name in os.listdir(dir_hum):
    if name.endswith(".csv"):
        file_names.append(name)

# %%
# Create empty list to store all dataframes from all the csv files
dfs = []

# Iterate over files in directory and save dataframe to dfs
for file in file_names:
    df = pd.read_csv(os.path.join(dir_hum, file))
    dfs.append(df)

# Concatenate all dataframes in dfs
df = pd.concat(dfs, ignore_index=True)

# Save concatenated dataframe to csv
df.to_csv("../data_jsk/temperature_data.csv", index=False)

# %%
df
# Out:
#          datetime      mean_t  min_t  max_t  homeid
# 0      2018-02-20  172.944122  164.0  182.0     299
# 1      2018-02-21  166.892131  152.0  176.0     299
# 2      2018-02-22  167.959710  153.0  176.0     299
# 3      2018-02-23  164.040397  142.0  177.0     299
# 4      2018-02-24  159.414724  136.0  181.0     299
# ...           ...         ...    ...    ...     ...
# 71010  2018-06-26  208.935495  206.0  213.0     280
# 71011  2018-06-27  210.504754  207.0  215.0     280
# 71012  2018-06-28  213.664361  208.0  220.0     280
# 71013  2018-06-29  210.950648  208.0  214.0     280
# 71014  2018-06-30  206.914388  205.0  209.0     280
#
# [71015 rows x 5 columns]
