# %%
import os
import pandas as pd

# %% [markdown]
# ## Locate all files in the directory

# %%
directory = r"../data/original/"
file_names = []

for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_names.append(filename)

# %%
print(f'No of files: {len(file_names)}')
# Out:
# No of files: 118

# %%
# Check file house name
file_names[0].split('home')[1].split('.')[0]
# Out:
# '299'

# %%
directory+file_names[0].split('home')[1].split('.')[0]
# Out:
# '../data/original/299'

# %% [markdown]
# ## Define master function to transform the data

# %%
def transform_file(file_name):
    df = pd.read_csv(file_name, header=None)

    #rename the columns
    df.columns = ['datetime', 'power (watts)']

    #convert datetime column to datetime object
    df['datetime'] = pd.to_datetime(df['datetime'])

    #add column with time difference
    df_consp = df.copy().reset_index(drop=True, inplace=False)
    df_consp['time (s)'] = df_consp['datetime'].diff().dt.seconds

    # calculate energy consumption in watt-hours
    df_consp['Consumption (kWh)'] = df_consp['power (watts)'] * df_consp['time (s)'] / (3600*1000)

    # calculate daily consumption
    df_daily = df_consp.resample('D', on='datetime').sum()

    # Only save the rows where time is 24 hours
    df_daily = df_daily[df_daily['time (s)']==86400]

    # Drop unwanted columns
    df_daily.drop(['power (watts)'], axis=1, inplace=True)
    df_daily.drop(['time (s)'], axis=1, inplace=True)

    df_daily['homeid'] = filename.split('home')[1].split('.')[0]
    df_daily.reset_index(inplace=True)

    #print(f'{file_name} transformed successfully!')

    return df_daily

# %% [markdown]
# ## Save new file and delete original file

# %%
# export dataframe to csv file and delete original file
def export_file(df, file_name):
    df.to_csv('../data/data_transformed/' + file_name, index=False)
    print(f'{file_name} exported successfully!')

    original_path = directory + file_name

    if os.path.exists(original_path):
        os.remove(original_path)
        print(f'Original {file_name} deleted successfully!')
        print('----------------------------------------------\n')

# %%
# loop through all files in the directory and transform them
status = 1
for file_name in file_names:
    print(f'Processing file {status} of {len(file_names)}')
    df = transform_file(directory + file_name)
    export_file(df, file_name)
    status += 1
# Out:
# Processing file 1 of 118
# home299.csv exported successfully!
# Original home299.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 2 of 118
# home266.csv exported successfully!
# Original home266.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 3 of 118
# home272.csv exported successfully!
# Original home272.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 4 of 118
# home306.csv exported successfully!
# Original home306.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 5 of 118
# home307.csv exported successfully!
# Original home307.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 6 of 118
# home313.csv exported successfully!
# Original home313.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 7 of 118
# home273.csv exported successfully!
# Original home273.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 8 of 118
# home267.csv exported successfully!
# Original home267.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 9 of 118
# home298.csv exported successfully!
# Original home298.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 10 of 118
# home271.csv exported successfully!
# Original home271.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 11 of 118
# home265.csv exported successfully!
# Original home265.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 12 of 118
# home259.csv exported successfully!
# Original home259.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 13 of 118
# home305.csv exported successfully!
# Original home305.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 14 of 118
# home311.csv exported successfully!
# Original home311.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 15 of 118
# home310.csv exported successfully!
# Original home310.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 16 of 118
# home304.csv exported successfully!
# Original home304.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 17 of 118
# home258.csv exported successfully!
# Original home258.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 18 of 118
# home264.csv exported successfully!
# Original home264.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 19 of 118
# home270.csv exported successfully!
# Original home270.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 20 of 118
# home248.csv exported successfully!
# Original home248.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 21 of 118
# home274.csv exported successfully!
# Original home274.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 22 of 118
# home260.csv exported successfully!
# Original home260.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 23 of 118
# home328.csv exported successfully!
# Original home328.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 24 of 118
# home300.csv exported successfully!
# Original home300.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 25 of 118
# home315.csv exported successfully!
# Original home315.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 26 of 118
# home301.csv exported successfully!
# Original home301.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 27 of 118
# home329.csv exported successfully!
# Original home329.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 28 of 118
# home261.csv exported successfully!
# Original home261.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 29 of 118
# home275.csv exported successfully!
# Original home275.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 30 of 118
# home249.csv exported successfully!
# Original home249.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 31 of 118
# home288.csv exported successfully!
# Original home288.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 32 of 118
# home263.csv exported successfully!
# Original home263.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 33 of 118
# home277.csv exported successfully!
# Original home277.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 34 of 118
# home317.csv exported successfully!
# Original home317.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 35 of 118
# home303.csv exported successfully!
# Original home303.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 36 of 118
# home302.csv exported successfully!
# Original home302.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 37 of 118
# home316.csv exported successfully!
# Original home316.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 38 of 118
# home276.csv exported successfully!
# Original home276.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 39 of 118
# home262.csv exported successfully!
# Original home262.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 40 of 118
# home289.csv exported successfully!
# Original home289.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 41 of 118
# home211.csv exported successfully!
# Original home211.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 42 of 118
# home239.csv exported successfully!
# Original home239.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 43 of 118
# home238.csv exported successfully!
# Original home238.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 44 of 118
# home212.csv exported successfully!
# Original home212.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 45 of 118
# home213.csv exported successfully!
# Original home213.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 46 of 118
# home216.csv exported successfully!
# Original home216.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 47 of 118
# home228.csv exported successfully!
# Original home228.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 48 of 118
# home214.csv exported successfully!
# Original home214.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 49 of 118
# home215.csv exported successfully!
# Original home215.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 50 of 118
# home229.csv exported successfully!
# Original home229.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 51 of 118
# home224.csv exported successfully!
# Original home224.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 52 of 118
# home230.csv exported successfully!
# Original home230.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 53 of 118
# home218.csv exported successfully!
# Original home218.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 54 of 118
# home219.csv exported successfully!
# Original home219.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 55 of 118
# home231.csv exported successfully!
# Original home231.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 56 of 118
# home225.csv exported successfully!
# Original home225.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 57 of 118
# home233.csv exported successfully!
# Original home233.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 58 of 118
# home227.csv exported successfully!
# Original home227.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 59 of 118
# home226.csv exported successfully!
# Original home226.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 60 of 118
# home232.csv exported successfully!
# Original home232.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 61 of 118
# home236.csv exported successfully!
# Original home236.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 62 of 118
# home222.csv exported successfully!
# Original home222.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 63 of 118
# home237.csv exported successfully!
# Original home237.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 64 of 118
# home221.csv exported successfully!
# Original home221.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 65 of 118
# home235.csv exported successfully!
# Original home235.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 66 of 118
# home234.csv exported successfully!
# Original home234.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 67 of 118
# home284.csv exported successfully!
# Original home284.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 68 of 118
# home290.csv exported successfully!
# Original home290.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 69 of 118
# home247.csv exported successfully!
# Original home247.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 70 of 118
# home253.csv exported successfully!
# Original home253.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 71 of 118
# home333.csv exported successfully!
# Original home333.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 72 of 118
# home327.csv exported successfully!
# Original home327.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 73 of 118
# home326.csv exported successfully!
# Original home326.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 74 of 118
# home332.csv exported successfully!
# Original home332.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 75 of 118
# home252.csv exported successfully!
# Original home252.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 76 of 118
# home246.csv exported successfully!
# Original home246.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 77 of 118
# home291.csv exported successfully!
# Original home291.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 78 of 118
# home285.csv exported successfully!
# Original home285.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 79 of 118
# home293.csv exported successfully!
# Original home293.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 80 of 118
# home287.csv exported successfully!
# Original home287.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 81 of 118
# home250.csv exported successfully!
# Original home250.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 82 of 118
# home244.csv exported successfully!
# Original home244.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 83 of 118
# home278.csv exported successfully!
# Original home278.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 84 of 118
# home330.csv exported successfully!
# Original home330.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 85 of 118
# home318.csv exported successfully!
# Original home318.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 86 of 118
# home319.csv exported successfully!
# Original home319.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 87 of 118
# home331.csv exported successfully!
# Original home331.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 88 of 118
# home325.csv exported successfully!
# Original home325.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 89 of 118
# home279.csv exported successfully!
# Original home279.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 90 of 118
# home245.csv exported successfully!
# Original home245.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 91 of 118
# home251.csv exported successfully!
# Original home251.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 92 of 118
# home286.csv exported successfully!
# Original home286.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 93 of 118
# home292.csv exported successfully!
# Original home292.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 94 of 118
# home296.csv exported successfully!
# Original home296.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 95 of 118
# home282.csv exported successfully!
# Original home282.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 96 of 118
# home269.csv exported successfully!
# Original home269.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 97 of 118
# home255.csv exported successfully!
# Original home255.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 98 of 118
# home241.csv exported successfully!
# Original home241.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 99 of 118
# home309.csv exported successfully!
# Original home309.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 100 of 118
# home321.csv exported successfully!
# Original home321.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 101 of 118
# home335.csv exported successfully!
# Original home335.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 102 of 118
# home334.csv exported successfully!
# Original home334.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 103 of 118
# home320.csv exported successfully!
# Original home320.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 104 of 118
# home308.csv exported successfully!
# Original home308.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 105 of 118
# home240.csv exported successfully!
# Original home240.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 106 of 118
# home254.csv exported successfully!
# Original home254.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 107 of 118
# home268.csv exported successfully!
# Original home268.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 108 of 118
# home283.csv exported successfully!
# Original home283.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 109 of 118
# home281.csv exported successfully!
# Original home281.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 110 of 118
# home295.csv exported successfully!
# Original home295.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 111 of 118
# home242.csv exported successfully!
# Original home242.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 112 of 118
# home256.csv exported successfully!
# Original home256.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 113 of 118
# home322.csv exported successfully!
# Original home322.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 114 of 118
# home323.csv exported successfully!
# Original home323.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 115 of 118
# home257.csv exported successfully!
# Original home257.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 116 of 118
# home243.csv exported successfully!
# Original home243.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 117 of 118
# home294.csv exported successfully!
# Original home294.csv deleted successfully!
# ----------------------------------------------
#
# Processing file 118 of 118
# home280.csv exported successfully!
# Original home280.csv deleted successfully!
# ----------------------------------------------
