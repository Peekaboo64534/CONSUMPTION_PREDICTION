# %%
import os
import sys
import pandas as pd
import numpy as np

# %%
# Assign directory
directory = r"/Users/peekaboo645/Desktop/home 240/gas"

file_names = []

# Iterate over files in directory
for name in os.listdir(directory):
        file_names.append(name)

# %%
file_names
# Out:
# ['home208_hall1934_sensor11878_gas-pulse_gas.csv',
#  'home148_hall1372_sensor7334_gas-pulse_gas.csv',
#  'home239_hall2217_sensor14194_gas-pulse_gas.csv',
#  'home164_study1490_sensor8223_gas-pulse_gas.csv',
#  'home154_outside1427_sensor7745_gas-pulse_gas.csv',
#  'home93_bathroom982_sensor3905_gas-pulse_gas.csv',
#  'home86_other925_sensor3473_gas-pulse_gas.csv',
#  'home62_hall705_sensor1672_gas-pulse_gas.csv',
#  'home199_outside1853_sensor11118_gas-pulse_gas.csv',
#  'home311_bathroom2854_sensor20133_gas-pulse_gas.csv',
#  'home151_hall1397_sensor7536_gas-pulse_gas.csv',
#  'home327_outside2975_sensor21230_gas-pulse_gas.csv',
#  'home290_other2695_sensor18665_gas-pulse_gas.csv',
#  'home330_outside2997_sensor21449_gas-pulse_gas.csv',
#  'home275_hall2545_sensor17017_gas-pulse_gas.csv',
#  'home273_outside2537_sensor16904_gas-pulse_gas.csv',
#  'home94_hall990_sensor3982_gas-pulse_gas.csv',
#  'home305_outside2800_sensor19712_gas-pulse_gas.csv',
#  'home318_kitchen2898_sensor20449_gas-pulse_gas.csv',
#  'home177_hall1671_sensor9787_gas-pulse_gas.csv',
#  'home89_outside946_sensor3627_gas-pulse_gas.csv',
#  'home115_outside1149_sensor5417_gas-pulse_gas.csv',
#  'home179_hall1655_sensor9641_gas-pulse_gas.csv',
#  'home207_outside1933_sensor11789_gas-pulse_gas.csv',
#  'home75_hall813_sensor2639_gas-pulse_gas.csv',
#  'home270_outside2502_sensor16670_gas-pulse_gas.csv',
#  'home122_hall1218_sensor6054_gas-pulse_gas.csv',
#  'home300_hall2759_sensor19356_gas-pulse_gas.csv',
#  'home200_outside1875_sensor11227_gas-pulse_gas.csv',
#  'home123_hall1226_sensor6144_gas-pulse_gas.csv',
#  'home234_hall2176_sensor13846_gas-pulse_gas.csv',
#  'home243_outside2256_sensor14454_gas-pulse_gas.csv',
#  'home70_hall774_sensor2304_gas-pulse_gas.csv',
#  'home328_hall2976_sensor21279_gas-pulse_gas.csv',
#  'home267_hall2458_sensor16353_gas-pulse_gas.csv',
#  'home158_bathroom1451_sensor7942_gas-pulse_gas.csv',
#  'home261_outside2407_sensor15901_gas-pulse_gas.csv',
#  'home242_hall2243_sensor14934_gas-pulse_gas.csv',
#  'home301_outside2766_sensor19392_gas-pulse_gas.csv',
#  'home294_hall2708_sensor18940_gas-pulse_gas.csv',
#  'home149_outside1389_sensor7439_gas-pulse_gas.csv',
#  'home82_utility890_sensor3234_gas-pulse_gas.csv',
#  'home285_hall2639_sensor17934_gas-pulse_gas.csv',
#  'home193_outside1810_sensor10841_gas-pulse_gas.csv',
#  'home219_hall2019_sensor12540_gas-pulse_gas.csv',
#  '.DS_Store',
#  'home73_utility783_sensor2374_gas-pulse_gas.csv',
#  'home226_hall2089_sensor13078_gas-pulse_gas.csv',
#  'home246_outside2275_sensor14641_gas-pulse_gas.csv',
#  'home325_outside2957_sensor21112_gas-pulse_gas.csv',
#  'home326_outside2965_sensor21161_gas-pulse_gas.csv',
#  'home109_outside1101_sensor5018_gas-pulse_gas.csv',
#  'home210_outside1943_sensor11893_gas-pulse_gas.csv',
#  'home79_hall835_sensor2798_gas-pulse_gas.csv',
#  'home98_hall1019_sensor4298_gas-pulse_gas.csv',
#  'home162_hall1618_sensor9352_gas-pulse_gas.csv',
#  'home218_kitchen2012_sensor12409_gas-pulse_gas.csv',
#  'home190_hall1768_sensor10545_gas-pulse_gas.csv',
#  'home283_outside2623_sensor17800_gas-pulse_gas.csv',
#  'home253_utility2327_sensor15147_gas-pulse_gas.csv',
#  'home125_hall1244_sensor6257_gas-pulse_gas.csv',
#  'home85_hall919_sensor3420_gas-pulse_gas.csv',
#  'home144_kitchen1336_sensor7054_gas-pulse_gas.csv',
#  'home65_outside730_sensor1903_gas-pulse_gas.csv',
#  'home150_hall1391_sensor7505_gas-pulse_gas.csv',
#  'home247_hall2287_sensor14791_gas-pulse_gas.csv',
#  'home134_outside1277_sensor6481_gas-pulse_gas.csv',
#  'home114_hall1141_sensor5398_gas-pulse_gas.csv',
#  'home235_outside2214_sensor14125_gas-pulse_gas.csv',
#  'home99_outside1028_sensor4391_gas-pulse_gas.csv',
#  'home332_kitchen3032_sensor21894_gas-pulse_gas.csv',
#  'home254_outside2347_sensor15294_gas-pulse_gas.csv',
#  'home138_livingroom1306_sensor6711_gas-pulse_gas.csv',
#  'home281_outside2609_sensor17676_gas-pulse_gas.csv',
#  'home286_kitchen2650_sensor18076_gas-pulse_gas.csv',
#  'home276_outside2553_sensor17057_gas-pulse_gas.csv',
#  'home139_bathroom1314_sensor6790_gas-pulse_gas.csv',
#  'home97_hall1010_sensor4219_gas-pulse_gas.csv',
#  'home215_hall1998_sensor12246_gas-pulse_gas.csv',
#  'home333_hall3015_sensor21766_gas-pulse_gas.csv',
#  'home194_study1821_sensor10900_gas-pulse_gas.csv',
#  'home169_outside1541_sensor8590_gas-pulse_gas.csv',
#  'home161_bedroom1478_sensor8143_gas-pulse_gas.csv',
#  'home69_hall788_sensor2401_gas-pulse_gas.csv',
#  'home175_livingroom1635_sensor9491_gas-pulse_gas.csv',
#  'home120_livingroom1168_sensor5589_gas-pulse_gas.csv',
#  'home268_hall2470_sensor16416_gas-pulse_gas.csv',
#  'home249_hall2306_sensor14905_gas-pulse_gas.csv',
#  'home308_outside2829_sensor19926_gas-pulse_gas.csv',
#  'home76_kitchen856_sensor2907_gas-pulse_gas.csv',
#  'home228_hall2105_sensor13334_gas-pulse_gas.csv',
#  'home155_outside1440_sensor7825_gas-pulse_gas.csv',
#  'home187_outside1748_sensor10335_gas-pulse_gas.csv',
#  'home232_outside2146_sensor13605_gas-pulse_gas.csv',
#  'home309_kitchen2838_sensor19981_gas-pulse_gas.csv',
#  'home146_other1356_sensor7169_gas-pulse_gas.csv',
#  'home201_kitchen1885_sensor11308_gas-pulse_gas.csv',
#  'home145_hall1345_sensor7112_gas-pulse_gas.csv',
#  'home278_hall2569_sensor17187_gas-pulse_gas.csv',
#  'home216_bedroom2004_sensor12294_gas-pulse_gas.csv',
#  'home238_hall2195_sensor14065_gas-pulse_gas.csv',
#  'home197_hall1840_sensor11055_gas-pulse_gas.csv',
#  'home296_hall2735_sensor19136_gas-pulse_gas.csv',
#  'home118_hall1162_sensor5531_gas-pulse_gas.csv',
#  'home289_kitchen2694_sensor18681_gas-pulse_gas.csv',
#  'home317_hall2892_sensor20423_gas-pulse_gas.csv',
#  'home119_study1217_sensor5985_gas-pulse_gas.csv',
#  'home147_bedroom1370_sensor7269_gas-pulse_gas.csv',
#  'home191_outside1791_sensor10698_gas-pulse_gas.csv',
#  'home277_livingroom2562_sensor17134_gas-pulse_gas.csv',
#  'home265_hall2497_sensor16622_gas-pulse_gas.csv',
#  'home192_hall1800_sensor10759_gas-pulse_gas.csv',
#  'home96_livingroom997_sensor4112_gas-pulse_gas.csv',
#  'home166_outside1516_sensor8408_gas-pulse_gas.csv',
#  'home116_kitchen1156_sensor5483_gas-pulse_gas.csv',
#  'home143_hall1327_sensor6962_gas-pulse_gas.csv',
#  'home272_hall2516_sensor16761_gas-pulse_gas.csv',
#  'home92_utility971_sensor3836_gas-pulse_gas.csv',
#  'home195_hall1828_sensor10940_gas-pulse_gas.csv',
#  'home291_outside2660_sensor18223_gas-pulse_gas.csv',
#  'home264_outside2439_sensor16192_gas-pulse_gas.csv',
#  'home299_outside2752_sensor19262_gas-pulse_gas.csv',
#  'home124_hall1237_sensor6202_gas-pulse_gas.csv',
#  'home163_outside1626_sensor9400_gas-pulse_gas.csv',
#  'home319_outside2907_sensor20509_gas-pulse_gas.csv',
#  'home126_outside1187_sensor5743_gas-pulse_gas.csv',
#  'home263_outside2429_sensor16127_gas-pulse_gas.csv',
#  'home222_outside2036_sensor12671_gas-pulse_gas.csv',
#  'home227_hall2099_sensor13245_gas-pulse_gas.csv',
#  'home331_hall2999_sensor21610_gas-pulse_gas.csv',
#  'home211_outside1959_sensor12010_gas-pulse_gas.csv',
#  'home186_outside1781_sensor10617_gas-pulse_gas.csv',
#  'home315_other2870_sensor20239_gas-pulse_gas.csv',
#  'home225_bathroom2080_sensor13032_gas-pulse_gas.csv',
#  'home171_outside1568_sensor8765_gas-pulse_gas.csv',
#  'home67_outside765_sensor2222_gas-pulse_gas.csv',
#  'home135_hall1281_sensor6543_gas-pulse_gas.csv',
#  'home160_utility1467_sensor8078_gas-pulse_gas.csv',
#  'home244_livingroom2259_sensor14554_gas-pulse_gas.csv',
#  'home266_outside2448_sensor16244_gas-pulse_gas.csv',
#  'home241_hall2236_sensor14335_gas-pulse_gas.csv',
#  'home100_hall1039_sensor4478_gas-pulse_gas.csv',
#  'home121_hall1174_sensor5655_gas-pulse_gas.csv',
#  'home233_hall2163_sensor13756_gas-pulse_gas.csv',
#  'home229_hall2111_sensor13416_gas-pulse_gas.csv',
#  'home110_outside1093_sensor4947_gas-pulse_gas.csv',
#  'home170_hall1553_sensor8665_gas-pulse_gas.csv',
#  'home113_hall1201_sensor5927_gas-pulse_gas.csv',
#  'home323_hall2929_sensor20927_gas-pulse_gas.csv',
#  'home182_hall1701_sensor10017_gas-pulse_gas.csv',
#  'home63_outside719_sensor1845_gas-pulse_gas.csv',
#  'home269_kitchen2473_sensor16504_gas-pulse_gas.csv',
#  'home129_hall1190_sensor5802_gas-pulse_gas.csv',
#  'home304_outside2792_sensor19646_gas-pulse_gas.csv',
#  'home167_cupboard1521_sensor8454_gas-pulse_gas.csv',
#  'home231_outside2141_sensor13554_gas-pulse_gas.csv',
#  'home66_utility745_sensor2036_gas-pulse_gas.csv',
#  'home256_hall2369_sensor15594_gas-pulse_gas.csv',
#  'home279_bedroom2585_sensor17362_gas-pulse_gas.csv',
#  'home287_hall2672_sensor18498_gas-pulse_gas.csv',
#  'home223_outside2052_sensor12769_gas-pulse_gas.csv',
#  'home205_hall1921_sensor11721_gas-pulse_gas.csv',
#  'home81_outside877_sensor3156_gas-pulse_gas.csv',
#  'home141_kitchen1322_sensor6888_gas-pulse_gas.csv',
#  'home74_utility804_sensor2552_gas-pulse_gas.csv',
#  'home313_bedroom2867_sensor20195_gas-pulse_gas.csv',
#  'home230_outside2134_sensor13491_gas-pulse_gas.csv',
#  'home251_hall2321_sensor15042_gas-pulse_gas.csv',
#  'home188_outside1757_sensor10377_gas-pulse_gas.csv',
#  'home307_outside2817_sensor19841_gas-pulse_gas.csv',
#  'home185_outside1737_sensor10234_gas-pulse_gas.csv',
#  'home137_hall1295_sensor6663_gas-pulse_gas.csv',
#  'home274_hall2543_sensor17044_gas-pulse_gas.csv',
#  'home107_outside1074_sensor4719_gas-pulse_gas.csv',
#  'home329_utility2983_sensor21330_gas-pulse_gas.csv',
#  'home140_livingroom1318_sensor6843_gas-pulse_gas.csv',
#  'home64_cupboard712_sensor1787_gas-pulse_gas.csv',
#  'home334_hall3013_sensor21778_gas-pulse_gas.csv',
#  'home174_cupboard1592_sensor8957_gas-pulse_gas.csv',
#  'home156_hall1443_sensor7911_gas-pulse_gas.csv',
#  'home212_outside1967_sensor12053_gas-pulse_gas.csv',
#  'home181_outside1698_sensor9942_gas-pulse_gas.csv',
#  'home280_hall2590_sensor17520_gas-pulse_gas.csv',
#  'home206_outside1912_sensor11572_gas-pulse_gas.csv',
#  'home61_outside694_sensor1570_gas-pulse_gas.csv',
#  'home320_hall2919_sensor20832_gas-pulse_gas.csv',
#  'home214_outside1988_sensor12175_gas-pulse_gas.csv',
#  'home310_hall2844_sensor20040_gas-pulse_gas.csv',
#  'home302_bedroom2769_sensor19464_gas-pulse_gas.csv',
#  'home335_utility3044_sensor21975_gas-pulse_gas.csv',
#  'home72_kitchen797_sensor2481_gas-pulse_gas.csv',
#  'home153_hall1416_sensor7706_gas-pulse_gas.csv',
#  'home101_outside1044_sensor4504_gas-pulse_gas.csv',
#  'home176_outside1642_sensor9545_gas-pulse_gas.csv',
#  'home221_kitchen2029_sensor12606_gas-pulse_gas.csv',
#  'home322_hall2936_sensor21003_gas-pulse_gas.csv',
#  'home213_hall1974_sensor12134_gas-pulse_gas.csv',
#  'home165_cupboard1501_sensor8301_gas-pulse_gas.csv',
#  'home173_outside1590_sensor8938_gas-pulse_gas.csv',
#  'home83_hall899_sensor3302_gas-pulse_gas.csv',
#  'home106_kitchen1085_sensor4884_gas-pulse_gas.csv',
#  'home184_outside1803_sensor10793_gas-pulse_gas.csv',
#  'home240_hall2226_sensor14265_gas-pulse_gas 12.07.08.csv',
#  'home271_outside2521_sensor16767_gas-pulse_gas.csv',
#  'home84_outside906_sensor3358_gas-pulse_gas.csv',
#  'home306_outside2809_sensor19769_gas-pulse_gas.csv',
#  'home178_outside1685_sensor9867_gas-pulse_gas.csv',
#  'home248_hall2299_sensor14832_gas-pulse_gas.csv',
#  'home47_hall654_sensor1221_gas-pulse_gas.csv',
#  'home293_bathroom2716_sensor18978_gas-pulse_gas.csv',
#  'home209_hall2062_sensor12868_gas-pulse_gas.csv',
#  'home80_hall873_sensor3054_gas-pulse_gas.csv',
#  'home183_outside1924_sensor11743_gas-pulse_gas.csv',
#  'home284_outside2635_sensor17876_gas-pulse_gas.csv',
#  'home252_hall2329_sensor15171_gas-pulse_gas.csv',
#  'home321_hall2923_sensor20871_gas-pulse_gas.csv',
#  'home157_outside1616_sensor9309_gas-pulse_gas.csv',
#  'home105_kitchen1110_sensor5084_gas-pulse_gas.csv',
#  'home78_hall864_sensor2969_gas-pulse_gas.csv',
#  'home203_outside1905_sensor11464_gas-pulse_gas.csv',
#  'home303_outside2782_sensor19572_gas-pulse_gas.csv',
#  'home168_other1530_sensor8512_gas-pulse_gas.csv',
#  'home71_hall824_sensor2716_gas-pulse_gas.csv',
#  'home180_hall1662_sensor9709_gas-pulse_gas.csv',
#  'home288_hall2680_sensor18566_gas-pulse_gas.csv',
#  'home77_outside827_sensor2745_gas-pulse_gas.csv',
#  'home245_outside2279_sensor14653_gas-pulse_gas.csv',
#  'home88_outside936_sensor3555_gas-pulse_gas.csv',
#  'home236_outside2183_sensor13921_gas-pulse_gas.csv',
#  'home258_outside2383_sensor15681_gas-pulse_gas.csv',
#  'home159_livingroom1465_sensor8060_gas-pulse_gas.csv',
#  'home257_hall2377_sensor15634_gas-pulse_gas.csv',
#  'home133_outside1267_sensor6422_gas-pulse_gas.csv',
#  'home128_hall1250_sensor6323_gas-pulse_gas.csv',
#  'home202_outside1896_sensor11391_gas-pulse_gas.csv',
#  'home237_hall2189_sensor13997_gas-pulse_gas.csv',
#  'home295_hall2726_sensor19107_gas-pulse_gas.csv',
#  'home68_outside755_sensor2100_gas-pulse_gas.csv',
#  'home259_outside2486_sensor16559_gas-pulse_gas.csv',
#  'home260_outside2390_sensor15743_gas-pulse_gas.csv',
#  'home224_outside2070_sensor12913_gas-pulse_gas.csv',
#  'home316_outside2891_sensor20379_gas-pulse_gas.csv',
#  'home90_outside955_sensor3692_gas-pulse_gas.csv',
#  'home292_hall2662_sensor18255_gas-pulse_gas.csv',
#  'home282_outside2617_sensor17745_gas-pulse_gas.csv',
#  'home298_outside2746_sensor19235_gas-pulse_gas.csv',
#  'home91_hall963_sensor3761_gas-pulse_gas.csv',
#  'home152_outside1414_sensor7655_gas-pulse_gas.csv',
#  'home59_hall687_sensor1511_gas-pulse_gas.csv',
#  'home255_outside2367_sensor15510_gas-pulse_gas.csv',
#  'home189_hall1761_sensor10485_gas-pulse_gas.csv',
#  'home250_hall2314_sensor14982_gas-pulse_gas.csv',
#  'home136_outside1291_sensor6602_gas-pulse_gas.csv',
#  'home102_outside1052_sensor4567_gas-pulse_gas.csv',
#  'home262_outside2416_sensor15948_gas-pulse_gas.csv',
#  'home117_hall1198_sensor5872_gas-pulse_gas.csv']

# %%
split_names=file_names[0].split('_')

# %%
for file in file_names:
    new_name = file.split('_')[0] + '.csv'
    old_file = os.path.join(directory, file)

# %%
split_names
# Out:
# ['home208', 'hall1934', 'sensor11878', 'gas-pulse', 'gas.csv']

# %%
# !ls ..
# Out:
# CONSUMPTION_PREDICTION README.md              raw_data
